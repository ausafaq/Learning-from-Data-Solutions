# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
#generate a data set of 20. 
#for simplicity, 10 in the first quadrant, another 10 in the third quadrant 
X1 = []
Y1 = []
X2 = []
Y2 = []

#weight = [0,0,0]

for i in range(50):
    X1.append(random.uniform(0,1))
    Y1.append(random.uniform(0,1))
    X2.append(random.uniform(-1,0))
    Y2.append(random.uniform(-1,0))


#label the data
data1 = [np.array([1,X1[i],Y1[i],1]) for i in range(50)]
data2 = [np.array([1,X2[i],Y2[i],-1]) for i in range(50)]
data = data1 + data2
plt.plot(X1,Y1,'ro')
plt.plot(X2,Y2,'go')

# y = -x
x = np.linspace(-1,1,100)
y = -1 * x
plt.plot(x, y, color='purple')
plt.show()

# %%
x_point = []
y_point = []
count = 0
eta = 100
weight = [1,1,1]
w0=1
w1=1
w2=1
for i in range(len(data)):
        point = data[i]
        point.tolist()
        axes = plt.gca()
        plt.plot(X1,Y1,'ro')
        plt.plot(X2,Y2,'go')
        x_t = point[0:3]
        x_t = np.array(x_t)
        w_t = np.array(weight)
        w_transpose = np.transpose(w_t)
        s_t = np.sign(np.dot(w_transpose,x_t))  
        if(point[3]*s_t)<0 and count <1000:
            h_sub = (point[3]-s_t)*eta
            w0=w0+x[0]*(h_sub)*eta
            w1=w1+x[1]*(h_sub)*eta
            w2=w2+x[2]*(h_sub)*eta
            a=-w0/w2
            b=-w0/w1
            x_h = np.linspace(-1,1,100)
            y_h = (-(w1/w2))*x+(-w0/w2)
            plt.plot(x_h,y_h,color='black')
            plt.show()
            count += 1

# %%
x_point = []
y_point = []
count = 0
eta = 1
weight = [1,1,1]
w0=1
w1=1
w2=1
for i in range(len(data)):
        point = data[i]
        point.tolist()
        axes = plt.gca()
        plt.plot(X1,Y1,'ro')
        plt.plot(X2,Y2,'go')
        x_t = point[0:3]
        x_t = np.array(x_t)
        w_t = np.array(weight)
        w_transpose = np.transpose(w_t)
        s_t = np.sign(np.dot(w_transpose,x_t))  
        if(point[3]*s_t)<0 and count <1000:
            h_sub = (point[3]-s_t)*eta
            w0=w0+x[0]*(h_sub)*eta
            w1=w1+x[1]*(h_sub)*eta
            w2=w2+x[2]*(h_sub)*eta
            a=-w0/w2
            b=-w0/w1
            x_h = np.linspace(-1,1,100)
            y_h = (-(w1/w2))*x+(-w0/w2)
            plt.plot(x_h,y_h,color='black')
            plt.show()
            count += 1

# %%
x_point = []
y_point = []
count = 0
eta = 0.01
weight = [1,1,1]
w0=1
w1=1
w2=1
for i in range(len(data)):
        point = data[i]
        point.tolist()
        axes = plt.gca()
        plt.plot(X1,Y1,'ro')
        plt.plot(X2,Y2,'go')
        x_t = point[0:3]
        x_t = np.array(x_t)
        w_t = np.array(weight)
        w_transpose = np.transpose(w_t)
        s_t = np.sign(np.dot(w_transpose,x_t))  
        if(point[3]*s_t)<0 and count <1000:
            h_sub = (point[3]-s_t)*eta
            w0=w0+x[0]*(h_sub)*eta
            w1=w1+x[1]*(h_sub)*eta
            w2=w2+x[2]*(h_sub)*eta
            a=-w0/w2
            b=-w0/w1
            x_h = np.linspace(-1,1,100)
            y_h = (-(w1/w2))*x+(-w0/w2)
            plt.plot(x_h,y_h,color='black')
            plt.show()
            count += 1

# %%
x_point = []
y_point = []
count = 0
eta = 0.001
weight = [1,1,1]
w0=1
w1=1
w2=1
for i in range(len(data)):
        point = data[i]
        point.tolist()
        axes = plt.gca()
        plt.plot(X1,Y1,'ro')
        plt.plot(X2,Y2,'go')
        x_t = point[0:3]
        x_t = np.array(x_t)
        w_t = np.array(weight)
        w_transpose = np.transpose(w_t)
        s_t = np.sign(np.dot(w_transpose,x_t))  
        if(point[3]*s_t)<0 and count <1000:
            h_sub = (point[3]-s_t)*eta
            w0=w0+x[0]*(h_sub)*eta
            w1=w1+x[1]*(h_sub)*eta
            w2=w2+x[2]*(h_sub)*eta
            a=-w0/w2
            b=-w0/w1
            x_h = np.linspace(-1,1,100)
            y_h = (-(w1/w2))*x+(-w0/w2)
            plt.plot(x_h,y_h,color='black')
            plt.show()
            count += 1
